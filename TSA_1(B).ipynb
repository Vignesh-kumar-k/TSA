# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv', header=0)

df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

df['Month'] = pd.to_datetime(df['Month'], format='%Y-%m')
df.set_index('Month', inplace=True)
df.sort_index(inplace=True)

df['Year'] = df.index.year
df['Month_Num'] = df.index.month
df['Quarter'] = df.index.quarter

yearly_passengers = df.resample('Y').sum()

df_ffill = df.ffill()

df_ffill.to_csv('Cleaned_Airline_Passengers.csv')

print(df.head())
print(df_ffill.head())
# Out:
#             Passengers  Year  Month_Num  Quarter
# Month
# 1949-01-01         112  1949          1        1
# 1949-02-01         118  1949          2        1
# 1949-03-01         132  1949          3        1
# 1949-04-01         129  1949          4        2
# 1949-05-01         121  1949          5        2
#             Passengers  Year  Month_Num  Quarter
# Month
# 1949-01-01         112  1949          1        1
# 1949-02-01         118  1949          2        1
# 1949-03-01         132  1949          3        1
# 1949-04-01         129  1949          4        2
# 1949-05-01         121  1949          5        2
# <ipython-input-1-e81bc5a7f85d>:16: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_passengers = df.resample('Y').sum()
